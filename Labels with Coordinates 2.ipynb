# %%
# Pillow is installed but import PIL due to backward dependency
from PIL import Image
from tesserocr import PyTessBaseAPI, RIL

# %%
base = '/Users/macbook/Desktop/images/'
index = 28559
path = str(index) + '.png'
image = Image.open(path)

# %%
api = PyTessBaseAPI()
api.SetImage(image)
boxes = api.GetComponentImages(RIL.TEXTLINE, True)
print '-----------------------'
print 'Found {} text labels.'.format(len(boxes))
print '-----------------------'
# im is a PIL image object
# box is a dict with keys x, y, w and h
for i, (im, box, _, _) in enumerate(boxes):
    api.SetRectangle(box['x'], box['y'], box['w'], box['h'])
    ocrResult = api.GetUTF8Text()
    conf = api.MeanTextConf()
#     if conf < 70: continue
    print (u"[{0}]: x={x:3}, y={y:3}, w={w:3}, h={h:3}, "
           "confidence: {1:2}, text: {2}").format(i, conf, ocrResult, **box)
# Out:
# -----------------------
# Found 8 text labels.
# -----------------------
# [0]: x=129, y=103, w=183, h= 25, confidence:  0, text:
# [1]: x=129, y=145, w=176, h= 32, confidence: 81, text: containing
#
#
# [2]: x=129, y=178, w=961, h= 39, confidence: 88, text:
#
#
#
#
#
# copper power - Wire gauze
#
#
#
#
#
#
# [3]: x=906, y=277, w=217, h= 32, confidence: 86, text: Tripod stand
#
#
# [4]: x=907, y=384, w=120, h= 23, confidence: 84, text: Burner
#
#
# [5]: x=116, y=691, w=251, h= 41, confidence: 87, text: Figure 1.10
#
#
# [6]: x=118, y=734, w=1026, h= 57, confidence: 82, text: Oxidation of copper to 2Cu + 02 ﬂ
#
#
# [7]: x=118, y=793, w=240, h= 39, confidence: 86, text: copper oxide

# %%
from IPython.display import Image
Image(path)
